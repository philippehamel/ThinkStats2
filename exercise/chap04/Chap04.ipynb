# %% [markdown]
# # Chapitre 4

# %%
# %matplotlib inline

import numpy as np

import nsfg
import first
import thinkstats2
import thinkplot

# %% [markdown]
# **Question 4.4**
#
# À quel percentile de poids à la naissance est-ce que j'appartient?

# %%
live, firsts, others = first.MakeFrames()
weights_cdf = thinkstats2.Cdf(live.totalwgt_lb, label = 'Weights')

# %%
print("Étant un bébé de 8 lbs, mon percentile est : ", weights_cdf.PercentileRank(8))
# Out:
# Étant un bébé de 8 lbs, mon percentile est :  73.3237441912

# %% [markdown]
# **Exercise 4.2**
#
# The numbers generated by `numpy.random.random` are supposed to be uniform between 0 and 1; that is, every value in the range should have the same probability.
#
# Generate 1000 numbers from `numpy.random.random` and plot their PMF.  What goes wrong?
#
# Now plot the CDF. Is the distribution uniform?

# %%
sample = np.random.random(1000)
sample_pmf = thinkstats2.Pmf(sample, 'Random numbers')

thinkplot.Pmf(sample_pmf)
thinkplot.Config(xlabel = 'Numbers', ylabel = 'Pmf')

# %%
sample_cdf = thinkstats2.Cdf(sample, label = 'Random numbers')

thinkplot.Cdf(sample_cdf)
thinkplot.Config(xlabel = 'Number', ylabel = 'Cdf')
